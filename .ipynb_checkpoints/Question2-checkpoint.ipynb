# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X_train = np.loadtxt('X_train.csv')
X_test = np.loadtxt('X_test.csv')
Y_train = np.loadtxt('Y_train.csv')
Y_test = np.loadtxt('Y_test.csv')

# %%
def relu(z):
    a = np.maximum(0,z)
    return a

def Linear(z):
    return z

def sigmoid(z):
    return 1/(1 + np.exp(-z))

def initialize_params(layer_sizes):
    params = {}
    for i in range(1, len(layer_sizes)):
        params['W' + str(i)] = np.random.randn(layer_sizes[i], layer_sizes[i-1])*0.01
        params['B' + str(i)] = np.random.randn(layer_sizes[i],1)*0.01
    return params

def forward_propagation(X_train, params):
    layers = len(params)//2
    values = {}
    for i in range(1, layers+1):
        if i==1:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], X_train) + params['B' + str(i)]
            values['A' + str(i)] = relu(values['Z' + str(i)])
        else:
            values['Z' + str(i)] = np.dot(params['W' + str(i)], values['A' + str(i-1)]) + params['B' + str(i)]
            if i==layers:
                values['A' + str(i)] = values['Z' + str(i)]
            else:
                values['A' + str(i)] = relu(values['Z' + str(i)])
    return values

def mean_squared_error(Y, YH):
    return np.square(Y - YH).mean()

def compute_cost(values, Y_train):
    layers = len(values)//2
    Y_pred = values['A' + str(layers)]
    cost = 1/(2*len(Y_train)) * np.sum(np.square(Y_pred - Y_train))
    return cost

def backward_propagation(params, values, X_train, Y_train):
    layers = len(params)//2
    m = len(Y_train)
    grads = {}
    for i in range(layers,0,-1):
        if i==layers:
            dA = 1/m * (values['A' + str(i)] - Y_train)
            dZ = dA
        else:
            dA = np.dot(params['W' + str(i+1)].T, dZ)
            dZ = np.multiply(dA, np.where(values['A' + str(i)]>=0, 1, 0))
        if i==1:
            grads['W' + str(i)] = 1/m * np.dot(dZ, X_train.T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
        else:
            grads['W' + str(i)] = 1/m * np.dot(dZ,values['A' + str(i-1)].T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
    return grads

def update_params(params, grads, learning_rate):
    layers = len(params)//2
    params_updated = {}
    for i in range(1,layers+1):
        params_updated['W' + str(i)] = params['W' + str(i)] - learning_rate * grads['W' + str(i)]
        params_updated['B' + str(i)] = params['B' + str(i)] - learning_rate * grads['B' + str(i)]
    return params_updated

def model(X_train, Y_train, layer_sizes, num_iters, learning_rate):
    
    def train_accuracy(X_train, Y_train):
        values_train = forward_propagation(X_train.T, params)
        train_acc = np.sqrt(mean_squared_error(Y_train, values_train['A' + str(len(layer_sizes)-1)].T))
        return train_acc
                       
    params = initialize_params(layer_sizes)
    error = []
    acc = []
    for i in range(num_iters):
        values = forward_propagation(X_train.T, params)
        cost = compute_cost(values, Y_train.T)
        accuracy = train_accuracy(X_train, Y_train)
        grads = backward_propagation(params, values,X_train.T, Y_train.T)
        params = update_params(params, grads, learning_rate)
        if i % 100 == 0:
            print('Cost at iteration ' + str(i+1) + ' = ' + str(cost) + '\n')
        error.append(cost)
        acc.append(accuracy)
        
    print('average_cost: ', np.sum(np.array(error))/num_iters)
    
    return params, np.array(error), np.array(acc)

def compute_accuracy(X_train, X_test, Y_train, Y_test, params):
    values_train = forward_propagation(X_train.T, params)
    values_test = forward_propagation(X_test.T, params)
    train_acc = np.sqrt(mean_squared_error(Y_train, values_train['A' + str(len(layer_sizes)-1)].T))
    test_acc = np.sqrt(mean_squared_error(Y_test, values_test['A' + str(len(layer_sizes)-1)].T))
    return train_acc, test_acc

def predict(X, params):
    values = forward_propagation(X.T, params)
    predictions = values['A' + str(len(values)//2)].T
    return predictions

# %%
layer_sizes = [2, 8, 1]                                                           #set layer sizes
num_iters = 2000                                                                  #set epochs
learning_rate = 0.01                                                              #set learning rate
params, error, accuracy = model(X_train, Y_train, layer_sizes, num_iters, learning_rate)           #train the model
train_acc, test_acc = compute_accuracy(X_train, X_test, Y_train, Y_test, params)  #get accuracy
print('Root Mean Squared Error on Training Data = ' + str(train_acc))
print('Root Mean Squared Error on Test Data = ' + str(test_acc))
# Out:
# Cost at iteration 1 = 2858.3963544645285
#
# Cost at iteration 2 = 2858.3893016600027
#
# Cost at iteration 3 = 2858.3822484142665
#
# Cost at iteration 4 = 2858.3751946226735
#
# Cost at iteration 5 = 2858.3681401802214
#
# Cost at iteration 6 = 2858.3610854161834
#
# Cost at iteration 7 = 2858.3540310778335
#
# Cost at iteration 8 = 2858.346976648117
#
# Cost at iteration 9 = 2858.339921814784
#
# Cost at iteration 10 = 2858.332867969316
#
# Cost at iteration 11 = 2858.3258138393485
#
# Cost at iteration 12 = 2858.31875976318
#
# Cost at iteration 13 = 2858.31170429413
#
# Cost at iteration 14 = 2858.304647187284
#
# Cost at iteration 15 = 2858.2975885556248
#
# Cost at iteration 16 = 2858.2905279930415
#
# Cost at iteration 17 = 2858.2834668370633
#
# Cost at iteration 18 = 2858.276405466753
#
# Cost at iteration 19 = 2858.2693426546275
#
# Cost at iteration 20 = 2858.262278060004
#
# Cost at iteration 21 = 2858.255211383598
#
# Cost at iteration 22 = 2858.248142589978
#
# Cost at iteration 23 = 2858.2410725597147
#
# Cost at iteration 24 = 2858.234001757386
#
# Cost at iteration 25 = 2858.2269301463048
#
# Cost at iteration 26 = 2858.219856759773
#
# Cost at iteration 27 = 2858.212780881527
#
# Cost at iteration 28 = 2858.205702829106
#
# Cost at iteration 29 = 2858.19862252548
#
# Cost at iteration 30 = 2858.1915406954445
#
# Cost at iteration 31 = 2858.1844610727458
#
# Cost at iteration 32 = 2858.17738027282
#
# Cost at iteration 33 = 2858.1702966368503
#
# Cost at iteration 34 = 2858.163210947157
#
# Cost at iteration 35 = 2858.156122629215
#
# Cost at iteration 36 = 2858.1490320613534
#
# Cost at iteration 37 = 2858.141938224834
#
# Cost at iteration 38 = 2858.1348409978705
#
# Cost at iteration 39 = 2858.1277403965673
#
# Cost at iteration 40 = 2858.1206365320554
#
# Cost at iteration 41 = 2858.1135291416367
#
# Cost at iteration 42 = 2858.106417758548
#
# Cost at iteration 43 = 2858.09930226984
#
# Cost at iteration 44 = 2858.0921823277913
#
# Cost at iteration 45 = 2858.085058557335
#
# Cost at iteration 46 = 2858.0779310067587
#
# Cost at iteration 47 = 2858.0707999210504
#
# Cost at iteration 48 = 2858.0636653448273
#
# Cost at iteration 49 = 2858.0565290835493
#
# Cost at iteration 50 = 2858.0493899544067
#
# Cost at iteration 51 = 2858.0422462783654
#
# Cost at iteration 52 = 2858.0350976629456
#
# Cost at iteration 53 = 2858.0279439903843
#
# Cost at iteration 54 = 2858.0207851419377
#
# Cost at iteration 55 = 2858.013620456607
#
# Cost at iteration 56 = 2858.0064495874676
#
# Cost at iteration 57 = 2857.9992732340475
#
# Cost at iteration 58 = 2857.9920911562363
#
# Cost at iteration 59 = 2857.9849028978665
#
# Cost at iteration 60 = 2857.9777087492607
#
# Cost at iteration 61 = 2857.9705090521365
#
# Cost at iteration 62 = 2857.9633054081023
#
# Cost at iteration 63 = 2857.9560955085226
#
# Cost at iteration 64 = 2857.948878681876
#
# Cost at iteration 65 = 2857.9416552389453
#
# Cost at iteration 66 = 2857.934425099275
#
# Cost at iteration 67 = 2857.927188191133
#
# Cost at iteration 68 = 2857.919945829991
#
# Cost at iteration 69 = 2857.912696670393
#
# Cost at iteration 70 = 2857.9054411884867
#
# Cost at iteration 71 = 2857.8981797207953
#
# Cost at iteration 72 = 2857.8909110059303
#
# Cost at iteration 73 = 2857.883635359622
#
# Cost at iteration 74 = 2857.8763530074184
#
# Cost at iteration 75 = 2857.869065439384
#
# Cost at iteration 76 = 2857.8617701979324
#
# Cost at iteration 77 = 2857.8544667284714
#
# Cost at iteration 78 = 2857.847156631254
#
# Cost at iteration 79 = 2857.839842584515
#
# Cost at iteration 80 = 2857.8325253742664
#
# Cost at iteration 81 = 2857.8252007629326
#
# Cost at iteration 82 = 2857.8178683962064
#
# Cost at iteration 83 = 2857.8105294284132
#
# Cost at iteration 84 = 2857.803182783838
#
# Cost at iteration 85 = 2857.7958269615724
#
# Cost at iteration 86 = 2857.788462109404
#
# Cost at iteration 87 = 2857.781090803261
#
# Cost at iteration 88 = 2857.773710326251
#
# Cost at iteration 89 = 2857.7663200170505
#
# Cost at iteration 90 = 2857.758921106761
#
# Cost at iteration 91 = 2857.7515157034354
#
# Cost at iteration 92 = 2857.7441014859155
#
# Cost at iteration 93 = 2857.736677848376
#
# Cost at iteration 94 = 2857.729244701905
#
# Cost at iteration 95 = 2857.721801692443
#
# Cost at iteration 96 = 2857.7143491151514
#
# Cost at iteration 97 = 2857.706886695566
#
# Cost at iteration 98 = 2857.6994166497093
#
# Cost at iteration 99 = 2857.6919378325083
#
# Cost at iteration 100 = 2857.6844503066127
#
# Cost at iteration 101 = 2857.6769538444273
#
# Cost at iteration 102 = 2857.669445773021
#
# Cost at iteration 103 = 2857.661927765703
#
# Cost at iteration 104 = 2857.6544005974133
#
# Cost at iteration 105 = 2857.646862146642
#
# Cost at iteration 106 = 2857.639312270513
#
# Cost at iteration 107 = 2857.631753139379
#
# Cost at iteration 108 = 2857.624186740699
#
# Cost at iteration 109 = 2857.616608001615
#
# Cost at iteration 110 = 2857.609016967987
#
# Cost at iteration 111 = 2857.6014133013778
#
# Cost at iteration 112 = 2857.5937973343075
#
# Cost at iteration 113 = 2857.5861720796743
#
# Cost at iteration 114 = 2857.578536370963
#
# Cost at iteration 115 = 2857.570889658927
#
# Cost at iteration 116 = 2857.563230970207
#
# Cost at iteration 117 = 2857.5555580286414
#
# Cost at iteration 118 = 2857.5478717684955
#
# Cost at iteration 119 = 2857.5401715928638
#
# Cost at iteration 120 = 2857.532458045759
#
# Cost at iteration 121 = 2857.5247317240824
#
# Cost at iteration 122 = 2857.516992590819
#
# Cost at iteration 123 = 2857.509240565743
#
# Cost at iteration 124 = 2857.501474203276
#
# Cost at iteration 125 = 2857.493693132034
#
# Cost at iteration 126 = 2857.485897263992
#
# Cost at iteration 127 = 2857.478086446529
#
# Cost at iteration 128 = 2857.4702603482006
#
# Cost at iteration 129 = 2857.4624188298417
#
# Cost at iteration 130 = 2857.454561731304
#
# Cost at iteration 131 = 2857.446689609293
#
# Cost at iteration 132 = 2857.438802776274
#
# Cost at iteration 133 = 2857.4309035724814
#
# Cost at iteration 134 = 2857.4229892683793
#
# Cost at iteration 135 = 2857.41505806414
#
# Cost at iteration 136 = 2857.4071103063593
#
# Cost at iteration 137 = 2857.399148169732
#
# Cost at iteration 138 = 2857.391168823193
#
# Cost at iteration 139 = 2857.383172340047
#
# Cost at iteration 140 = 2857.3751585434143
#
# Cost at iteration 141 = 2857.3671318499273
#
# Cost at iteration 142 = 2857.3590906779013
#
# Cost at iteration 143 = 2857.351031460293
#
# Cost at iteration 144 = 2857.3429546692937
#
# Cost at iteration 145 = 2857.3348596066344
#
# Cost at iteration 146 = 2857.3267475635516
#
# Cost at iteration 147 = 2857.3186176003273
#
# Cost at iteration 148 = 2857.3104704451243
#
# Cost at iteration 149 = 2857.3023027168338
#
# Cost at iteration 150 = 2857.294115332489
#
# Cost at iteration 151 = 2857.2859082253267
#
# Cost at iteration 152 = 2857.2776821858897
#
# Cost at iteration 153 = 2857.2694370840245
#
# Cost at iteration 154 = 2857.2611713325928
#
# Cost at iteration 155 = 2857.252884668078
#
# Cost at iteration 156 = 2857.244576949323
#
# Cost at iteration 157 = 2857.236249230303
#
# Cost at iteration 158 = 2857.227899948942
#
# Cost at iteration 159 = 2857.219529103696
#
# Cost at iteration 160 = 2857.2111372357044
#
# Cost at iteration 161 = 2857.202725408965
#
# Cost at iteration 162 = 2857.1942903882596
#
# Cost at iteration 163 = 2857.1858320678307
#
# Cost at iteration 164 = 2857.1773503802337
#
# Cost at iteration 165 = 2857.1688450460965
#
# Cost at iteration 166 = 2857.160315822222
#
# Cost at iteration 167 = 2857.1517624057465
#
# Cost at iteration 168 = 2857.143184428205
#
# Cost at iteration 169 = 2857.1345815749955
#
# Cost at iteration 170 = 2857.125954788122
#
# Cost at iteration 171 = 2857.117303967913
#
# Cost at iteration 172 = 2857.1086273716005
#
# Cost at iteration 173 = 2857.0999246708207
#
# Cost at iteration 174 = 2857.0911978499876
#
# Cost at iteration 175 = 2857.082444381601
#
# Cost at iteration 176 = 2857.0736659266354
#
# Cost at iteration 177 = 2857.064860475327
#
# Cost at iteration 178 = 2857.056027402152
#
# Cost at iteration 179 = 2857.047166299177
#
# Cost at iteration 180 = 2857.0382794638604
#
# Cost at iteration 181 = 2857.0293668327477
#
# Cost at iteration 182 = 2857.020425069384
#
# Cost at iteration 183 = 2857.011455134771
#
# Cost at iteration 184 = 2857.002455554744
#
# Cost at iteration 185 = 2856.9934259414276
#
# Cost at iteration 186 = 2856.984365913493
#
# Cost at iteration 187 = 2856.975276009067
#
# Cost at iteration 188 = 2856.966155469764
#
# Cost at iteration 189 = 2856.9570039726964
#
# Cost at iteration 190 = 2856.9478215364975
#
# Cost at iteration 191 = 2856.938607050363
#
# Cost at iteration 192 = 2856.9293596214056
#
# Cost at iteration 193 = 2856.9200792011816
#
# Cost at iteration 194 = 2856.9107652780453
#
# Cost at iteration 195 = 2856.901417419204
#
# Cost at iteration 196 = 2856.8920352018677
#
# Cost at iteration 197 = 2856.8826188819367
#
# Cost at iteration 198 = 2856.873167554529
#
# Cost at iteration 199 = 2856.8636806058475
#
# Cost at iteration 200 = 2856.8541575935515
#
# Cost at iteration 201 = 2856.8445971308556
#
# Cost at iteration 202 = 2856.834999099047
#
# Cost at iteration 203 = 2856.82536445733
#
# Cost at iteration 204 = 2856.815692854521
# Cost at iteration 205 = 2856.8059824575616
#
# Cost at iteration 206 = 2856.796233124051
#
# Cost at iteration 207 = 2856.786444171417
#
# Cost at iteration 208 = 2856.776617106949
#
# Cost at iteration 209 = 2856.766750334512
#
# Cost at iteration 210 = 2856.7568434187124
#
# Cost at iteration 211 = 2856.746896891413
#
# Cost at iteration 212 = 2856.7369082283208
#
# Cost at iteration 213 = 2856.7268773343003
#
# Cost at iteration 214 = 2856.716803711273
#
# Cost at iteration 215 = 2856.706688023923
#
# Cost at iteration 216 = 2856.696528564775
#
# Cost at iteration 217 = 2856.686324794855
#
# Cost at iteration 218 = 2856.676076168791
#
# Cost at iteration 219 = 2856.6657821347367
#
# Cost at iteration 220 = 2856.655442134288
#
# Cost at iteration 221 = 2856.6450554949092
#
# Cost at iteration 222 = 2856.6346210906318
#
# Cost at iteration 223 = 2856.62413898893
#
# Cost at iteration 224 = 2856.613608722384
#
# Cost at iteration 225 = 2856.6030307084147
#
# Cost at iteration 226 = 2856.5924041331873
#
# Cost at iteration 227 = 2856.5817274008696
#
# Cost at iteration 228 = 2856.57100060998
#
# Cost at iteration 229 = 2856.560224807648
#
# Cost at iteration 230 = 2856.549398223076
#
# Cost at iteration 231 = 2856.538519215265
#
# Cost at iteration 232 = 2856.5275872558304
#
# Cost at iteration 233 = 2856.5166018901637
#
# Cost at iteration 234 = 2856.5055621654483
#
# Cost at iteration 235 = 2856.494467417406
#
# Cost at iteration 236 = 2856.4833169738245
#
# Cost at iteration 237 = 2856.472110154454
#
# Cost at iteration 238 = 2856.460846270917
#
# Cost at iteration 239 = 2856.449524626602
#
# Cost at iteration 240 = 2856.4381445165614
#
# Cost at iteration 241 = 2856.426705227412
#
# Cost at iteration 242 = 2856.4152060372294
#
# Cost at iteration 243 = 2856.4036477555446
#
# Cost at iteration 244 = 2856.3920286554517
#
# Cost at iteration 245 = 2856.3803473450703
#
# Cost at iteration 246 = 2856.368602653597
#
# Cost at iteration 247 = 2856.3567943511666
#
# Cost at iteration 248 = 2856.344921662679
#
# Cost at iteration 249 = 2856.33298450644
#
# Cost at iteration 250 = 2856.320981738688
#
# Cost at iteration 251 = 2856.30891222658
#
# Cost at iteration 252 = 2856.2967752877803
#
# Cost at iteration 253 = 2856.284570197125
#
# Cost at iteration 254 = 2856.272296452504
#
# Cost at iteration 255 = 2856.259952825054
#
# Cost at iteration 256 = 2856.247538315225
#
# Cost at iteration 257 = 2856.235052705079
#
# Cost at iteration 258 = 2856.2224947815307
#
# Cost at iteration 259 = 2856.2098633731202
#
# Cost at iteration 260 = 2856.197157586534
#
# Cost at iteration 261 = 2856.184376697421
#
# Cost at iteration 262 = 2856.1715196566174
#
# Cost at iteration 263 = 2856.1585851862505
#
# Cost at iteration 264 = 2856.1455726156955
#
# Cost at iteration 265 = 2856.1324814098184
#
# Cost at iteration 266 = 2856.119312296256
#
# Cost at iteration 267 = 2856.1060637723654
#
# Cost at iteration 268 = 2856.092733403638
#
# Cost at iteration 269 = 2856.079320196249
#
# Cost at iteration 270 = 2856.065824627615
#
# Cost at iteration 271 = 2856.0522462599215
#
# Cost at iteration 272 = 2856.0385822884186
#
# Cost at iteration 273 = 2856.024831831686
#
# Cost at iteration 274 = 2856.010993994679
#
# Cost at iteration 275 = 2855.9970672025697
#
# Cost at iteration 276 = 2855.9830502383656
#
# Cost at iteration 277 = 2855.9689416901524
#
# Cost at iteration 278 = 2855.954741245215
#
# Cost at iteration 279 = 2855.940448162021
#
# Cost at iteration 280 = 2855.92606052975
#
# Cost at iteration 281 = 2855.911577865648
#
# Cost at iteration 282 = 2855.896999078522
#
# Cost at iteration 283 = 2855.8823221519724
#
# Cost at iteration 284 = 2855.8675461081307
#
# Cost at iteration 285 = 2855.852670133825
#
# Cost at iteration 286 = 2855.8376945179775
#
# Cost at iteration 287 = 2855.822616182565
#
# Cost at iteration 288 = 2855.8074338817883
#
# Cost at iteration 289 = 2855.792146354751
#
# Cost at iteration 290 = 2855.776752325268
#
# Cost at iteration 291 = 2855.7612505016764
#
# Cost at iteration 292 = 2855.745639843625
#
# Cost at iteration 293 = 2855.729920221634
#
# Cost at iteration 294 = 2855.714088871858
#
# Cost at iteration 295 = 2855.6981444393173
#
# Cost at iteration 296 = 2855.6820860616963
#
# Cost at iteration 297 = 2855.6659139615176
#
# Cost at iteration 298 = 2855.649624734957
#
# Cost at iteration 299 = 2855.6332166071666
#
# Cost at iteration 300 = 2855.6166890486784
#
# Cost at iteration 301 = 2855.6000405865816
#
# Cost at iteration 302 = 2855.583270397488
#
# Cost at iteration 303 = 2855.566375782118
#
# Cost at iteration 304 = 2855.549355231552
#
# Cost at iteration 305 = 2855.5322072215426
#
# Cost at iteration 306 = 2855.5149312997396
#
# Cost at iteration 307 = 2855.497524176396
#
# Cost at iteration 308 = 2855.4799849030287
#
# Cost at iteration 309 = 2855.462311876657
#
# Cost at iteration 310 = 2855.4445045741327
#
# Cost at iteration 311 = 2855.4265634719754
#
# Cost at iteration 312 = 2855.408483780197
#
# Cost at iteration 313 = 2855.3902638176373
#
# Cost at iteration 314 = 2855.3719018826605
#
# Cost at iteration 315 = 2855.353396203766
#
# Cost at iteration 316 = 2855.334745038001
#
# Cost at iteration 317 = 2855.315947188384
#
# Cost at iteration 318 = 2855.297000393883
#
# Cost at iteration 319 = 2855.2779028122995
#
# Cost at iteration 320 = 2855.258652673114
#
# Cost at iteration 321 = 2855.239248243447
#
# Cost at iteration 322 = 2855.2196874789893
#
# Cost at iteration 323 = 2855.199968478471
#
# Cost at iteration 324 = 2855.180089321256
#
# Cost at iteration 325 = 2855.160048081401
#
# Cost at iteration 326 = 2855.1398430069044
#
# Cost at iteration 327 = 2855.1194720720828
#
# Cost at iteration 328 = 2855.0989332114814
#
# Cost at iteration 329 = 2855.0782242477626
#
# Cost at iteration 330 = 2855.0573431154894
#
# Cost at iteration 331 = 2855.0362876444347
#
# Cost at iteration 332 = 2855.015055677281
#
# Cost at iteration 333 = 2854.9936460332447
#
# Cost at iteration 334 = 2854.9720557973346
#
# Cost at iteration 335 = 2854.9502826965827
#
# Cost at iteration 336 = 2854.9283245097317
#
# Cost at iteration 337 = 2854.9061789883663
#
# Cost at iteration 338 = 2854.8838438565726
#
# Cost at iteration 339 = 2854.861316810606
#
# Cost at iteration 340 = 2854.838595177963
#
# Cost at iteration 341 = 2854.815676567598
#
# Cost at iteration 342 = 2854.792558956236
#
# Cost at iteration 343 = 2854.7692399288517
#
# Cost at iteration 344 = 2854.7457170227212
#
# Cost at iteration 345 = 2854.721987759357
#
# Cost at iteration 346 = 2854.6980498137477
#
# Cost at iteration 347 = 2854.6739010151778
#
# Cost at iteration 348 = 2854.649538255392
#
# Cost at iteration 349 = 2854.624957783284
#
# Cost at iteration 350 = 2854.600158368917
#
# Cost at iteration 351 = 2854.57513707121
#
# Cost at iteration 352 = 2854.5498911909963
#
# Cost at iteration 353 = 2854.5244179960137
#
# Cost at iteration 354 = 2854.4987147199095
#
# Cost at iteration 355 = 2854.4727785636474
#
# Cost at iteration 356 = 2854.44660669325
#
# Cost at iteration 357 = 2854.4201966742407
#
# Cost at iteration 358 = 2854.3935459402815
#
# Cost at iteration 359 = 2854.3666515080804
#
# Cost at iteration 360 = 2854.339509691523
#
# Cost at iteration 361 = 2854.3121175060905
#
# Cost at iteration 362 = 2854.2844719090976
#
# Cost at iteration 363 = 2854.256569815064
#
# Cost at iteration 364 = 2854.228408100644
#
# Cost at iteration 365 = 2854.199983604152
#
# Cost at iteration 366 = 2854.17129312509
#
# Cost at iteration 367 = 2854.1423334236647
#
# Cost at iteration 368 = 2854.1131012203005
#
# Cost at iteration 369 = 2854.08359319515
#
# Cost at iteration 370 = 2854.0538062339383
#
# Cost at iteration 371 = 2854.02373701498
#
# Cost at iteration 372 = 2853.993382242413
#
# Cost at iteration 373 = 2853.9627379784115
#
# Cost at iteration 374 = 2853.931800694517
#
# Cost at iteration 375 = 2853.9005668189093
#
# Cost at iteration 376 = 2853.869032735867
#
# Cost at iteration 377 = 2853.8371947852315
#
# Cost at iteration 378 = 2853.805049251472
#
# Cost at iteration 379 = 2853.772592349595
#
# Cost at iteration 380 = 2853.7398203261314
#
# Cost at iteration 381 = 2853.7067293375353
#
# Cost at iteration 382 = 2853.6733154141984
#
# Cost at iteration 383 = 2853.639574694214
#
# Cost at iteration 384 = 2853.6055031905867
#
# Cost at iteration 385 = 2853.571096867107
#
# Cost at iteration 386 = 2853.5363525174444
#
# Cost at iteration 387 = 2853.501265531293
#
# Cost at iteration 388 = 2853.4658313469904
#
# Cost at iteration 389 = 2853.4300457265795
#
# Cost at iteration 390 = 2853.393904379937
#
# Cost at iteration 391 = 2853.357402964137
#
# Cost at iteration 392 = 2853.320537082789
#
# Cost at iteration 393 = 2853.2833026602793
#
# Cost at iteration 394 = 2853.24569507685
#
# Cost at iteration 395 = 2853.2077095265868
#
# Cost at iteration 396 = 2853.1693413928374
#
# Cost at iteration 397 = 2853.1305860021002
#
# Cost at iteration 398 = 2853.0914386233108
#
# Cost at iteration 399 = 2853.0518944671285
#
# Cost at iteration 400 = 2853.011948685218
#
# Cost at iteration 401 = 2852.97159636951
#
# Cost at iteration 402 = 2852.9308325514726
#
# Cost at iteration 403 = 2852.889652201346
#
# Cost at iteration 404 = 2852.848050227395
#
# Cost at iteration 405 = 2852.806022337318
#
# Cost at iteration 406 = 2852.763562616612
#
# Cost at iteration 407 = 2852.7206656374224
#
# Cost at iteration 408 = 2852.677326052606
#
# Cost at iteration 409 = 2852.633538449108
#
# Cost at iteration 410 = 2852.5892973471414
#
# Cost at iteration 411 = 2852.544596175055
#
# Cost at iteration 412 = 2852.499430036006
#
# Cost at iteration 413 = 2852.4537935180992
#
# Cost at iteration 414 = 2852.4076808656077
#
# Cost at iteration 415 = 2852.361086175629
#
# Cost at iteration 416 = 2852.3140036194104
#
# Cost at iteration 417 = 2852.2664272300176
#
# Cost at iteration 418 = 2852.218350744382
#
# Cost at iteration 419 = 2852.1697681062738
#
# Cost at iteration 420 = 2852.120672702696
#
# Cost at iteration 421 = 2852.0710567939864
#
# Cost at iteration 422 = 2852.0209159928486
#
# Cost at iteration 423 = 2851.970243873767
#
# Cost at iteration 424 = 2851.919033944416
#
# Cost at iteration 425 = 2851.8672795972293
#
# Cost at iteration 426 = 2851.8149741623247
#
# Cost at iteration 427 = 2851.762110887506
#
# Cost at iteration 428 = 2851.7086829372342
#
# Cost at iteration 429 = 2851.654683391609
#
# Cost at iteration 430 = 2851.6001052453107
#
# Cost at iteration 431 = 2851.544941406548
#
# Cost at iteration 432 = 2851.4891846865776
# Cost at iteration 433 = 2851.4328272785115
#
# Cost at iteration 434 = 2851.3758623586764
#
# Cost at iteration 435 = 2851.3182824781793
#
# Cost at iteration 436 = 2851.260080232249
#
# Cost at iteration 437 = 2851.2012481010443
#
# Cost at iteration 438 = 2851.1417781136574
#
# Cost at iteration 439 = 2851.0816624466643
#
# Cost at iteration 440 = 2851.0208931800425
#
# Cost at iteration 441 = 2850.959461813134
#
# Cost at iteration 442 = 2850.8973605371248
#
# Cost at iteration 443 = 2850.8345812935004
#
# Cost at iteration 444 = 2850.7711157634367
#
# Cost at iteration 445 = 2850.7069555253884
#
# Cost at iteration 446 = 2850.6420920538194
#
# Cost at iteration 447 = 2850.5765167179193
#
# Cost at iteration 448 = 2850.5102207802984
#
# Cost at iteration 449 = 2850.443195395677
#
# Cost at iteration 450 = 2850.375431609548
#
# Cost at iteration 451 = 2850.306920356836
#
# Cost at iteration 452 = 2850.237652460521
#
# Cost at iteration 453 = 2850.1676186302666
#
# Cost at iteration 454 = 2850.096809461018
#
# Cost at iteration 455 = 2850.0252154315863
#
# Cost at iteration 456 = 2849.952826903216
#
# Cost at iteration 457 = 2849.8796341181355
#
# Cost at iteration 458 = 2849.805627634112
#
# Cost at iteration 459 = 2849.730798331238
#
# Cost at iteration 460 = 2849.655134813764
#
# Cost at iteration 461 = 2849.5786268338957
#
# Cost at iteration 462 = 2849.50126401732
#
# Cost at iteration 463 = 2849.423035861644
#
# Cost at iteration 464 = 2849.3439310376266
#
# Cost at iteration 465 = 2849.263938701584
#
# Cost at iteration 466 = 2849.1830486977738
#
# Cost at iteration 467 = 2849.1012500333304
#
# Cost at iteration 468 = 2849.0185320138235
#
# Cost at iteration 469 = 2848.934882833296
#
# Cost at iteration 470 = 2848.850291175149
#
# Cost at iteration 471 = 2848.7647468217892
#
# Cost at iteration 472 = 2848.678236909234
#
# Cost at iteration 473 = 2848.5907492537513
#
# Cost at iteration 474 = 2848.502271836084
#
# Cost at iteration 475 = 2848.412792488685
#
# Cost at iteration 476 = 2848.322298893882
#
# Cost at iteration 477 = 2848.230778582041
#
# Cost at iteration 478 = 2848.1382189297046
#
# Cost at iteration 479 = 2848.0446075339446
#
# Cost at iteration 480 = 2847.949932094386
#
# Cost at iteration 481 = 2847.8541785293546
#
# Cost at iteration 482 = 2847.7573335813963
#
# Cost at iteration 483 = 2847.6593838295767
#
# Cost at iteration 484 = 2847.56031568748
#
# Cost at iteration 485 = 2847.4601154011857
#
# Cost at iteration 486 = 2847.3587690472173
#
# Cost at iteration 487 = 2847.25626253047
#
# Cost at iteration 488 = 2847.1525815821096
#
# Cost at iteration 489 = 2847.047711757459
#
# Cost at iteration 490 = 2846.9416384338383
#
# Cost at iteration 491 = 2846.8343477611425
#
# Cost at iteration 492 = 2846.7258261191373
#
# Cost at iteration 493 = 2846.616056104088
#
# Cost at iteration 494 = 2846.5050223609933
#
# Cost at iteration 495 = 2846.3927092717163
#
# Cost at iteration 496 = 2846.279100455726
#
# Cost at iteration 497 = 2846.164180682467
#
# Cost at iteration 498 = 2846.047933826233
#
# Cost at iteration 499 = 2845.9303435628385
#
# Cost at iteration 500 = 2845.8113933672007
#
# Cost at iteration 501 = 2845.6910665109026
#
# Cost at iteration 502 = 2845.569346077787
#
# Cost at iteration 503 = 2845.4462149219535
#
# Cost at iteration 504 = 2845.3216556757784
#
# Cost at iteration 505 = 2845.1956507725035
#
# Cost at iteration 506 = 2845.068182472068
#
# Cost at iteration 507 = 2844.9392328305103
#
# Cost at iteration 508 = 2844.8087835277624
#
# Cost at iteration 509 = 2844.676819157968
#
# Cost at iteration 510 = 2844.543318155072
#
# Cost at iteration 511 = 2844.4082615541265
#
# Cost at iteration 512 = 2844.2716302222098
#
# Cost at iteration 513 = 2844.13340479148
#
# Cost at iteration 514 = 2843.9935656563443
#
# Cost at iteration 515 = 2843.852092955621
#
# Cost at iteration 516 = 2843.708966570588
#
# Cost at iteration 517 = 2843.564166207434
#
# Cost at iteration 518 = 2843.4176712804874
#
# Cost at iteration 519 = 2843.269460951648
#
# Cost at iteration 520 = 2843.1195141273483
#
# Cost at iteration 521 = 2842.9678094554774
#
# Cost at iteration 522 = 2842.814325322287
#
# Cost at iteration 523 = 2842.659039849244
#
# Cost at iteration 524 = 2842.501930889852
#
# Cost at iteration 525 = 2842.3429737658976
#
# Cost at iteration 526 = 2842.1821472962333
#
# Cost at iteration 527 = 2842.0194291838
#
# Cost at iteration 528 = 2841.8547961762874
#
# Cost at iteration 529 = 2841.688224736979
#
# Cost at iteration 530 = 2841.519691041354
#
# Cost at iteration 531 = 2841.349170973652
#
# Cost at iteration 532 = 2841.1766401234026
#
# Cost at iteration 533 = 2841.0020737819164
#
# Cost at iteration 534 = 2840.8254469387284
#
# Cost at iteration 535 = 2840.6467342780184
#
# Cost at iteration 536 = 2840.4659101749717
#
# Cost at iteration 537 = 2840.282948692122
#
# Cost at iteration 538 = 2840.097823575632
#
# Cost at iteration 539 = 2839.9105082515534
#
# Cost at iteration 540 = 2839.7209758220274
#
# Cost at iteration 541 = 2839.52919906146
#
# Cost at iteration 542 = 2839.3351503297986
#
# Cost at iteration 543 = 2839.138798759735
#
# Cost at iteration 544 = 2838.940119178994
#
# Cost at iteration 545 = 2838.739083139297
#
# Cost at iteration 546 = 2838.5356615113124
#
# Cost at iteration 547 = 2838.3298250187195
#
# Cost at iteration 548 = 2838.1215440294222
#
# Cost at iteration 549 = 2837.9107885513827
#
# Cost at iteration 550 = 2837.69752822839
#
# Cost at iteration 551 = 2837.4817323358047
#
# Cost at iteration 552 = 2837.2633697762444
#
# Cost at iteration 553 = 2837.042409075228
#
# Cost at iteration 554 = 2836.818818376778
#
# Cost at iteration 555 = 2836.5925654389694
#
# Cost at iteration 556 = 2836.3636176294362
#
# Cost at iteration 557 = 2836.131941920834
#
# Cost at iteration 558 = 2835.8975048862476
#
# Cost at iteration 559 = 2835.6602726945566
#
# Cost at iteration 560 = 2835.4202111057552
#
# Cost at iteration 561 = 2835.1772854662154
#
# Cost at iteration 562 = 2834.931460703912
#
# Cost at iteration 563 = 2834.68270132359
#
# Cost at iteration 564 = 2834.430971401889
#
# Cost at iteration 565 = 2834.1762345824145
#
# Cost at iteration 566 = 2833.9184540707606
#
# Cost at iteration 567 = 2833.6575926294836
#
# Cost at iteration 568 = 2833.393612573025
#
# Cost at iteration 569 = 2833.1264757625813
#
# Cost at iteration 570 = 2832.856143600927
#
# Cost at iteration 571 = 2832.5825770271836
#
# Cost at iteration 572 = 2832.305736511534
#
# Cost at iteration 573 = 2832.0255820498983
#
# Cost at iteration 574 = 2831.7420731585376
#
# Cost at iteration 575 = 2831.455168868623
#
# Cost at iteration 576 = 2831.164827720742
#
# Cost at iteration 577 = 2830.8710077593573
#
# Cost at iteration 578 = 2830.573666527208
#
# Cost at iteration 579 = 2830.272761059661
#
# Cost at iteration 580 = 2829.9682478790132
#
# Cost at iteration 581 = 2829.660082988723
#
# Cost at iteration 582 = 2829.3482218676118
#
# Cost at iteration 583 = 2829.032619463993
#
# Cost at iteration 584 = 2828.713230189753
#
# Cost at iteration 585 = 2828.390007914379
#
# Cost at iteration 586 = 2828.062905958931
#
# Cost at iteration 587 = 2827.7318770899597
#
# Cost at iteration 588 = 2827.396873513364
#
# Cost at iteration 589 = 2827.0578468682065
#
# Cost at iteration 590 = 2826.714748220454
#
# Cost at iteration 591 = 2826.3675280566877
#
# Cost at iteration 592 = 2826.016136277727
#
# Cost at iteration 593 = 2825.6605221922323
#
# Cost at iteration 594 = 2825.300634510227
#
# Cost at iteration 595 = 2824.936421336567
#
# Cost at iteration 596 = 2824.567830164372
#
# Cost at iteration 597 = 2824.1948078683745
#
# Cost at iteration 598 = 2823.8173006982397
#
# Cost at iteration 599 = 2823.4352542718057
#
# Cost at iteration 600 = 2823.04861356829
#
# Cost at iteration 601 = 2822.657322921424
#
# Cost at iteration 602 = 2822.2613260125368
#
# Cost at iteration 603 = 2821.8605658635884
#
# Cost at iteration 604 = 2821.454984830141
#
# Cost at iteration 605 = 2821.0445245828255
#
# Cost at iteration 606 = 2820.629125978352
#
# Cost at iteration 607 = 2820.2087294824732
#
# Cost at iteration 608 = 2819.783274717968
#
# Cost at iteration 609 = 2819.3527006849577
#
# Cost at iteration 610 = 2818.916945504866
#
# Cost at iteration 611 = 2818.475946667127
#
# Cost at iteration 612 = 2818.0296409365988
#
# Cost at iteration 613 = 2817.5779643460423
#
# Cost at iteration 614 = 2817.120852188556
#
# Cost at iteration 615 = 2816.6582390099497
#
# Cost at iteration 616 = 2816.190058601072
#
# Cost at iteration 617 = 2815.716243990085
#
# Cost at iteration 618 = 2815.2367274346843
#
# Cost at iteration 619 = 2814.751440414275
#
# Cost at iteration 620 = 2814.2603136220832
#
# Cost at iteration 621 = 2813.7632769572388
#
# Cost at iteration 622 = 2813.2602593966817
#
# Cost at iteration 623 = 2812.7511893080514
#
# Cost at iteration 624 = 2812.2359941950526
#
# Cost at iteration 625 = 2811.714600700033
#
# Cost at iteration 626 = 2811.186934630863
#
# Cost at iteration 627 = 2810.652920952725
#
# Cost at iteration 628 = 2810.1124837798416
#
# Cost at iteration 629 = 2809.5655463671824
#
# Cost at iteration 630 = 2809.012031102112
#
# Cost at iteration 631 = 2808.451859496002
#
# Cost at iteration 632 = 2807.884952175795
#
# Cost at iteration 633 = 2807.3112288755406
#
# Cost at iteration 634 = 2806.7306084278807
#
# Cost at iteration 635 = 2806.143008755501
#
# Cost at iteration 636 = 2805.5483468625475
#
# Cost at iteration 637 = 2804.9465388222434
#
# Cost at iteration 638 = 2804.3374997331407
#
# Cost at iteration 639 = 2803.7211438372287
#
# Cost at iteration 640 = 2803.0973843779348
#
# Cost at iteration 641 = 2802.46613363671
#
# Cost at iteration 642 = 2801.8273029242573
#
# Cost at iteration 643 = 2801.1808025717187
#
# Cost at iteration 644 = 2800.526541921854
#
# Cost at iteration 645 = 2799.8644293201774
#
# Cost at iteration 646 = 2799.1943721060893
#
# Cost at iteration 647 = 2798.5162766039757
#
# Cost at iteration 648 = 2797.8300481142974
#
# Cost at iteration 649 = 2797.135590904659
#
# Cost at iteration 650 = 2796.4328082008683
#
# Cost at iteration 651 = 2795.7216021779723
#
# Cost at iteration 652 = 2795.0018739513034
#
# Cost at iteration 653 = 2794.2735235674973
#
# Cost at iteration 654 = 2793.536456832728
#
# Cost at iteration 655 = 2792.7905650701205
#
# Cost at iteration 656 = 2792.035744982761
#
# Cost at iteration 657 = 2791.2718922567497
#
# Cost at iteration 658 = 2790.4989014646867
#
# Cost at iteration 659 = 2789.7166660566977
#
# Cost at iteration 660 = 2788.9250783514935
#
# Cost at iteration 661 = 2788.1240295274238
#
# Cost at iteration 662 = 2787.313409613562
#
# Cost at iteration 663 = 2786.4931074807987
#
# Cost at iteration 664 = 2785.6630108329723
#
# Cost at iteration 665 = 2784.823006198012
#
# Cost at iteration 666 = 2783.9729789191206
#
# Cost at iteration 667 = 2783.112813145989
#
# Cost at iteration 668 = 2782.2423918260483
#
# Cost at iteration 669 = 2781.3615966957586
#
# Cost at iteration 670 = 2780.470308271954
#
# Cost at iteration 671 = 2779.568405843223
#
# Cost at iteration 672 = 2778.6557674613555
#
# Cost at iteration 673 = 2777.7322699328406
#
# Cost at iteration 674 = 2776.7977888104238
#
# Cost at iteration 675 = 2775.8521983847377
#
# Cost at iteration 676 = 2774.895371675999
#
# Cost at iteration 677 = 2773.927180425786
#
# Cost at iteration 678 = 2772.9474950888916
#
# Cost at iteration 679 = 2771.956184825267
#
# Cost at iteration 680 = 2770.95311749205
#
# Cost at iteration 681 = 2769.938159635702
#
# Cost at iteration 682 = 2768.9111764842305
#
# Cost at iteration 683 = 2767.8720319395325
#
# Cost at iteration 684 = 2766.820588569845
#
# Cost at iteration 685 = 2765.7567076023147
#
# Cost at iteration 686 = 2764.680248915691
#
# Cost at iteration 687 = 2763.5910710331623
#
# Cost at iteration 688 = 2762.4890311153104
#
# Cost at iteration 689 = 2761.3739849532208
#
# Cost at iteration 690 = 2760.2457869617465
#
# Cost at iteration 691 = 2759.1042901729215
#
# Cost at iteration 692 = 2757.9493462295427
#
# Cost at iteration 693 = 2756.7808053789236
#
# Cost at iteration 694 = 2755.5985164668273
#
# Cost at iteration 695 = 2754.40232693158
#
# Cost at iteration 696 = 2753.192082798393
#
# Cost at iteration 697 = 2751.967629771593
#
# Cost at iteration 698 = 2750.728810227727
#
# Cost at iteration 699 = 2749.475465665664
#
# Cost at iteration 700 = 2748.207436406147
#
# Cost at iteration 701 = 2746.9245613315748
#
# Cost at iteration 702 = 2745.6266778816494
#
# Cost at iteration 703 = 2744.3136220492797
#
# Cost at iteration 704 = 2742.9852283767505
#
# Cost at iteration 705 = 2741.6413299521573
#
# Cost at iteration 706 = 2740.281758406124
# Cost at iteration 707 = 2738.906343908817
#
# Cost at iteration 708 = 2737.5149151672526
#
# Cost at iteration 709 = 2736.1072994229257
#
# Cost at iteration 710 = 2734.683322449745
#
# Cost at iteration 711 = 2733.2428085523156
#
# Cost at iteration 712 = 2731.7855805645604
#
# Cost at iteration 713 = 2730.311459848684
#
# Cost at iteration 714 = 2728.820266294524
#
# Cost at iteration 715 = 2727.311818319257
#
# Cost at iteration 716 = 2725.785932867509
#
# Cost at iteration 717 = 2724.2424254118564
#
# Cost at iteration 718 = 2722.681109953746
#
# Cost at iteration 719 = 2721.1017990248315
#
# Cost at iteration 720 = 2719.5043036887614
#
# Cost at iteration 721 = 2717.8884335434
#
# Cost at iteration 722 = 2716.253996723525
#
# Cost at iteration 723 = 2714.6007999039934
#
# Cost at iteration 724 = 2712.9286483034025
#
# Cost at iteration 725 = 2711.2373456882488
#
# Cost at iteration 726 = 2709.52669437761
#
# Cost at iteration 727 = 2707.796495248354
#
# Cost at iteration 728 = 2706.0465477408966
#
# Cost at iteration 729 = 2704.276649865515
#
# Cost at iteration 730 = 2702.4865982092424
#
# Cost at iteration 731 = 2700.6761879433525
#
# Cost at iteration 732 = 2698.8452128314384
#
# Cost at iteration 733 = 2696.993465238123
#
# Cost at iteration 734 = 2695.1207361384086
#
# Cost at iteration 735 = 2693.226815127665
#
# Cost at iteration 736 = 2691.311490432296
#
# Cost at iteration 737 = 2689.3745489210905
#
# Cost at iteration 738 = 2687.4157761172646
#
# Cost at iteration 739 = 2685.4349562112384
#
# Cost at iteration 740 = 2683.431872074125
#
# Cost at iteration 741 = 2681.406305271995
#
# Cost at iteration 742 = 2679.358036080886
#
# Cost at iteration 743 = 2677.2868435026176
#
# Cost at iteration 744 = 2675.1925052814013
#
# Cost at iteration 745 = 2673.0747979212656
#
# Cost at iteration 746 = 2670.933496704336
#
# Cost at iteration 747 = 2668.76837570996
#
# Cost at iteration 748 = 2666.579207834708
#
# Cost at iteration 749 = 2664.3657648132767
#
# Cost at iteration 750 = 2662.1278172403004
#
# Cost at iteration 751 = 2659.865134593087
#
# Cost at iteration 752 = 2657.577485255318
#
# Cost at iteration 753 = 2655.2646365417036
#
# Cost at iteration 754 = 2652.926354723631
#
# Cost at iteration 755 = 2650.562405055829
#
# Cost at iteration 756 = 2648.1725518040394
#
# Cost at iteration 757 = 2645.7565582737498
#
# Cost at iteration 758 = 2643.314186839984
#
# Cost at iteration 759 = 2640.845198978181
#
# Cost at iteration 760 = 2638.3493552961686
#
# Cost at iteration 761 = 2635.826415567272
#
# Cost at iteration 762 = 2633.276138764553
#
# Cost at iteration 763 = 2630.6982830962206
#
# Cost at iteration 764 = 2628.0926060422144
#
# Cost at iteration 765 = 2625.4588643919938
#
# Cost at iteration 766 = 2622.7968142835434
#
# Cost at iteration 767 = 2620.106211243621
#
# Cost at iteration 768 = 2617.386810229261
#
# Cost at iteration 769 = 2614.638365670549
#
# Cost at iteration 770 = 2611.860631514708
#
# Cost at iteration 771 = 2609.053361271481
#
# Cost at iteration 772 = 2606.2163080598602
#
# Cost at iteration 773 = 2603.3492246561573
#
# Cost at iteration 774 = 2600.45186354345
#
# Cost at iteration 775 = 2597.5239769624204
#
# Cost at iteration 776 = 2594.5653169635775
#
# Cost at iteration 777 = 2591.5756354609325
#
# Cost at iteration 778 = 2588.5546842870867
#
# Cost at iteration 779 = 2585.5022152497936
#
# Cost at iteration 780 = 2582.4179801899786
#
# Cost at iteration 781 = 2579.3017310412624
#
# Cost at iteration 782 = 2576.1532198909763
#
# Cost at iteration 783 = 2572.9721990426983
#
# Cost at iteration 784 = 2569.7584210803298
#
# Cost at iteration 785 = 2566.5116389337104
#
# Cost at iteration 786 = 2563.2316059457985
#
# Cost at iteration 787 = 2559.918075941425
#
# Cost at iteration 788 = 2556.5708032976327
#
# Cost at iteration 789 = 2553.1895430156114
#
# Cost at iteration 790 = 2549.774050794247
#
# Cost at iteration 791 = 2546.3240831052813
#
# Cost at iteration 792 = 2542.8393972701037
#
# Cost at iteration 793 = 2539.319751538186
#
# Cost at iteration 794 = 2535.7649051671483
#
# Cost at iteration 795 = 2532.1746185044863
#
# Cost at iteration 796 = 2528.548653070956
#
# Cost at iteration 797 = 2524.8867716456125
#
# Cost at iteration 798 = 2521.1887383525236
#
# Cost at iteration 799 = 2517.45431874915
#
# Cost at iteration 800 = 2513.683279916395
#
# Cost at iteration 801 = 2509.875390550326
#
# Cost at iteration 802 = 2506.0304210555723
#
# Cost at iteration 803 = 2502.148143640385
#
# Cost at iteration 804 = 2498.22833241337
#
# Cost at iteration 805 = 2494.270763481879
#
# Cost at iteration 806 = 2490.2752150520614
#
# Cost at iteration 807 = 2486.2414675305627
#
# Cost at iteration 808 = 2482.169303627866
#
# Cost at iteration 809 = 2478.0585084632635
#
# Cost at iteration 810 = 2473.9088696714457
#
# Cost at iteration 811 = 2469.7201775107033
#
# Cost at iteration 812 = 2465.492224972718
#
# Cost at iteration 813 = 2461.224807893919
#
# Cost at iteration 814 = 2456.9177250684143
#
# Cost at iteration 815 = 2452.5707783624416
#
# Cost at iteration 816 = 2448.183772830344
#
# Cost at iteration 817 = 2443.756516832035
#
# Cost at iteration 818 = 2439.288822151923
#
# Cost at iteration 819 = 2434.780504119281
#
# Cost at iteration 820 = 2430.2313817300183
#
# Cost at iteration 821 = 2425.6412777698306
#
# Cost at iteration 822 = 2421.0100189386894
#
# Cost at iteration 823 = 2416.337435976637
#
# Cost at iteration 824 = 2411.623363790855
#
# Cost at iteration 825 = 2406.867641583943
#
# Cost at iteration 826 = 2402.0701129834024
#
# Cost at iteration 827 = 2397.2306261722374
#
# Cost at iteration 828 = 2392.3490340206613
#
# Cost at iteration 829 = 2387.425194218831
#
# Cost at iteration 830 = 2382.45896941058
#
# Cost at iteration 831 = 2377.450227328072
#
# Cost at iteration 832 = 2372.39884092734
#
# Cost at iteration 833 = 2367.3046885246326
#
# Cost at iteration 834 = 2362.167653933511
#
# Cost at iteration 835 = 2356.9876266026367
#
# Cost at iteration 836 = 2351.7645017541754
#
# Cost at iteration 837 = 2346.498180522745
#
# Cost at iteration 838 = 2341.1885700948396
#
# Cost at iteration 839 = 2335.835583848651
#
# Cost at iteration 840 = 2330.439141494209
#
# Cost at iteration 841 = 2324.999169213752
#
# Cost at iteration 842 = 2319.515599802267
#
# Cost at iteration 843 = 2313.988372808067
#
# Cost at iteration 844 = 2308.4174346733757
#
# Cost at iteration 845 = 2302.8027388747655
#
# Cost at iteration 846 = 2297.144246063408
#
# Cost at iteration 847 = 2291.441924204992
#
# Cost at iteration 848 = 2285.6957487192453
#
# Cost at iteration 849 = 2279.905702618935
#
# Cost at iteration 850 = 2274.0717766482435
#
# Cost at iteration 851 = 2268.1939694204225
#
# Cost at iteration 852 = 2262.2722875545946
#
# Cost at iteration 853 = 2256.3067458116107
#
# Cost at iteration 854 = 2250.297367228823
#
# Cost at iteration 855 = 2244.244183253674
#
# Cost at iteration 856 = 2238.147235510003
#
# Cost at iteration 857 = 2232.0065755388455
#
# Cost at iteration 858 = 2225.822256471957
#
# Cost at iteration 859 = 2219.594344708275
#
# Cost at iteration 860 = 2213.3229157025867
#
# Cost at iteration 861 = 2207.0080540893314
#
# Cost at iteration 862 = 2200.6498538043206
#
# Cost at iteration 863 = 2194.2484182042163
#
# Cost at iteration 864 = 2187.8038601836615
#
# Cost at iteration 865 = 2181.3163022898907
#
# Cost at iteration 866 = 2174.7858768347064
#
# Cost at iteration 867 = 2168.212726003653
#
# Cost at iteration 868 = 2161.5970019622664
#
# Cost at iteration 869 = 2154.9388669592367
#
# Cost at iteration 870 = 2148.2384934263473
#
# Cost at iteration 871 = 2141.4960640750373
#
# Cost at iteration 872 = 2134.711771989439
#
# Cost at iteration 873 = 2127.8858207157446
#
# Cost at iteration 874 = 2121.01842434775
#
# Cost at iteration 875 = 2114.1098076084245
#
# Cost at iteration 876 = 2107.1602059273596
#
# Cost at iteration 877 = 2100.169865513944
#
# Cost at iteration 878 = 2093.139043426118
#
# Cost at iteration 879 = 2086.068007634552
#
# Cost at iteration 880 = 2078.9570370821116
#
# Cost at iteration 881 = 2071.8064217384467
#
# Cost at iteration 882 = 2064.61646264957
#
# Cost at iteration 883 = 2057.3874719822775
#
# Cost at iteration 884 = 2050.119773063256
#
# Cost at iteration 885 = 2042.8137004127543
#
# Cost at iteration 886 = 2035.469599772659
#
# Cost at iteration 887 = 2028.0878281288517
#
# Cost at iteration 888 = 2020.6687537277016
#
# Cost at iteration 889 = 2013.2127560865638
#
# Cost at iteration 890 = 2005.7202259981568
#
# Cost at iteration 891 = 1998.1915655286905
#
# Cost at iteration 892 = 1990.6271880096122
#
# Cost at iteration 893 = 1983.0275180228684
#
# Cost at iteration 894 = 1975.3929913795516
#
# Cost at iteration 895 = 1967.7240550918254
#
# Cost at iteration 896 = 1960.0211673380234
#
# Cost at iteration 897 = 1952.2847974208146
#
# Cost at iteration 898 = 1944.5154257183392
#
# Cost at iteration 899 = 1936.713543628229
#
# Cost at iteration 900 = 1928.87965350441
#
# Cost at iteration 901 = 1921.0142685866272
#
# Cost at iteration 902 = 1913.1179129225918
#
# Cost at iteration 903 = 1905.1911212827074
#
# Cost at iteration 904 = 1897.2344390672915
#
# Cost at iteration 905 = 1889.2484222062494
#
# Cost at iteration 906 = 1881.2336370511473
#
# Cost at iteration 907 = 1873.190660259641
#
# Cost at iteration 908 = 1865.12007867223
#
# Cost at iteration 909 = 1857.022489181306
#
# Cost at iteration 910 = 1848.8984985924835
#
# Cost at iteration 911 = 1840.7487234781945
#
# Cost at iteration 912 = 1832.5737900235479
#
# Cost at iteration 913 = 1824.3743338644613
#
# Cost at iteration 914 = 1816.1509999180757
#
# Cost at iteration 915 = 1807.9044422054806
#
# Cost at iteration 916 = 1799.6353236667821
#
# Cost at iteration 917 = 1791.3443159685428
#
# Cost at iteration 918 = 1783.0320993036673
#
# Cost at iteration 919 = 1774.69936218377
#
# Cost at iteration 920 = 1766.3468012241092
#
# Cost at iteration 921 = 1757.975120921158
#
# Cost at iteration 922 = 1749.5850334229074
#
# Cost at iteration 923 = 1741.1772582919878
#
# Cost at iteration 924 = 1732.7525222617376
#
# Cost at iteration 925 = 1724.3115589853048
#
# Cost at iteration 926 = 1715.8551087779465
#
# Cost at iteration 927 = 1707.3839183526277
#
# Cost at iteration 928 = 1698.8987405490907
#
# Cost at iteration 929 = 1690.4003340565375
#
# Cost at iteration 930 = 1681.889463130101
#
# Cost at iteration 931 = 1673.366897301269
#
# Cost at iteration 932 = 1664.8334110824587
#
# Cost at iteration 933 = 1656.2897836659245
#
# Cost at iteration 934 = 1647.7367986172094
#
# Cost at iteration 935 = 1639.1752435633537
#
# Cost at iteration 936 = 1630.6059098760718
#
# Cost at iteration 937 = 1622.0295923501428
#
# Cost at iteration 938 = 1613.447088877241
#
# Cost at iteration 939 = 1604.8592001154582
#
# Cost at iteration 940 = 1596.2667291547748
#
# Cost at iteration 941 = 1587.6704811787367
#
# Cost at iteration 942 = 1579.0712631226133
#
# Cost at iteration 943 = 1570.469883328313
#
# Cost at iteration 944 = 1561.8671511963394
#
# Cost at iteration 945 = 1553.2638768350785
#
# Cost at iteration 946 = 1544.6608707077153
#
# Cost at iteration 947 = 1536.0589432770862
#
# Cost at iteration 948 = 1527.4589046487652
#
# Cost at iteration 949 = 1518.8615642127113
#
# Cost at iteration 950 = 1510.2677302837853
#
# Cost at iteration 951 = 1501.6782097414577
#
# Cost at iteration 952 = 1493.0938076690427
#
# Cost at iteration 953 = 1484.515326992781
#
# Cost at iteration 954 = 1475.9435681211014
#
# Cost at iteration 955 = 1467.3793285844072
#
# Cost at iteration 956 = 1458.8234026757052
#
# Cost at iteration 957 = 1450.2765810924416
# Cost at iteration 958 = 1441.7396505798515
#
# Cost at iteration 959 = 1433.2133935761958
#
# Cost at iteration 960 = 1424.6985878601952
#
# Cost at iteration 961 = 1416.1960062010164
#
# Cost at iteration 962 = 1407.7064160111483
#
# Cost at iteration 963 = 1399.230579002494
#
# Cost at iteration 964 = 1390.769250846021
#
# Cost at iteration 965 = 1382.323180835298
#
# Cost at iteration 966 = 1373.8931115542443
#
# Cost at iteration 967 = 1365.479778549421
#
# Cost at iteration 968 = 1357.083910007174
#
# Cost at iteration 969 = 1348.7062264359563
#
# Cost at iteration 970 = 1340.3474403541318
#
# Cost at iteration 971 = 1332.0082559835591
#
# Cost at iteration 972 = 1323.6893689492704
#
# Cost at iteration 973 = 1315.3914659855136
#
# Cost at iteration 974 = 1307.115224648464
#
# Cost at iteration 975 = 1298.861313035861
#
# Cost at iteration 976 = 1290.630389513856
#
# Cost at iteration 977 = 1282.4231024513124
#
# Cost at iteration 978 = 1274.2400899618262
#
# Cost at iteration 979 = 1266.0819796536928
#
# Cost at iteration 980 = 1257.9493883880623
#
# Cost at iteration 981 = 1249.8429220454943
#
# Cost at iteration 982 = 1241.7631753011322
#
# Cost at iteration 983 = 1233.7107314086913
#
# Cost at iteration 984 = 1225.6861619934452
#
# Cost at iteration 985 = 1217.6900268544016
#
# Cost at iteration 986 = 1209.722873775813
#
# Cost at iteration 987 = 1201.7852383481943
#
# Cost at iteration 988 = 1193.877643798977
#
# Cost at iteration 989 = 1186.0006008329335
#
# Cost at iteration 990 = 1178.1546074824855
#
# Cost at iteration 991 = 1170.3401489680023
#
# Cost at iteration 992 = 1162.557697568182
#
# Cost at iteration 993 = 1154.8077125005848
#
# Cost at iteration 994 = 1147.090639812396
#
# Cost at iteration 995 = 1139.406912281458
#
# Cost at iteration 996 = 1131.7569493276224
#
# Cost at iteration 997 = 1124.1411569344343
#
# Cost at iteration 998 = 1116.559927581179
#
# Cost at iteration 999 = 1109.0136401852728
#
# Cost at iteration 1000 = 1101.5026600549957
#
# Cost at iteration 1001 = 1094.0273388525422
#
# Cost at iteration 1002 = 1086.5880145673382
#
# Cost at iteration 1003 = 1079.1850114995905
#
# Cost at iteration 1004 = 1071.81864025399
#
# Cost at iteration 1005 = 1064.4891977435022
#
# Cost at iteration 1006 = 1057.1969672031535
#
# Cost at iteration 1007 = 1049.9422182137143
#
# Cost at iteration 1008 = 1042.7252067351685
#
# Cost at iteration 1009 = 1035.5461751498444
#
# Cost at iteration 1010 = 1028.4053523150794
#
# Cost at iteration 1011 = 1021.3029536252664
#
# Cost at iteration 1012 = 1014.2391810831357
#
# Cost at iteration 1013 = 1007.2142233801029
#
# Cost at iteration 1014 = 1000.2282559855093
#
# Cost at iteration 1015 = 993.2814412445754
#
# Cost at iteration 1016 = 986.3739284848713
#
# Cost at iteration 1017 = 979.5058541311024
#
# Cost at iteration 1018 = 972.6773418280095
#
# Cost at iteration 1019 = 965.8885168867962
#
# Cost at iteration 1020 = 959.1394658257487
#
# Cost at iteration 1021 = 952.4302720313664
#
# Cost at iteration 1022 = 945.7610093484252
#
# Cost at iteration 1023 = 939.1317319180562
#
# Cost at iteration 1024 = 932.5424924771258
#
# Cost at iteration 1025 = 925.9933343875563
#
# Cost at iteration 1026 = 919.4842843665026
#
# Cost at iteration 1027 = 913.0153577847526
#
# Cost at iteration 1028 = 906.586558857801
#
# Cost at iteration 1029 = 900.1978808423273
#
# Cost at iteration 1030 = 893.849306237804
#
# Cost at iteration 1031 = 887.5408069929675
#
# Cost at iteration 1032 = 881.2723447168672
#
# Cost at iteration 1033 = 875.0438657393958
#
# Cost at iteration 1034 = 868.8553417284544
#
# Cost at iteration 1035 = 862.706822800884
#
# Cost at iteration 1036 = 856.5980811384549
#
# Cost at iteration 1037 = 850.5290323877894
#
# Cost at iteration 1038 = 844.4995646284058
#
# Cost at iteration 1039 = 838.5095648094524
#
# Cost at iteration 1040 = 832.5588379143212
#
# Cost at iteration 1041 = 826.6473523085219
#
# Cost at iteration 1042 = 820.7749915657835
#
# Cost at iteration 1043 = 814.9415978076312
#
# Cost at iteration 1044 = 809.1470306296895
#
# Cost at iteration 1045 = 803.3911307625935
#
# Cost at iteration 1046 = 797.673736943453
#
# Cost at iteration 1047 = 791.9946847880485
#
# Cost at iteration 1048 = 786.3537983686624
#
# Cost at iteration 1049 = 780.7508719879381
#
# Cost at iteration 1050 = 775.1856579529649
#
# Cost at iteration 1051 = 769.6579259014749
#
# Cost at iteration 1052 = 764.167327437059
#
# Cost at iteration 1053 = 758.7139633134008
#
# Cost at iteration 1054 = 753.2976171563585
#
# Cost at iteration 1055 = 747.9180355059204
#
# Cost at iteration 1056 = 742.5749833842123
#
# Cost at iteration 1057 = 737.2682480770471
#
# Cost at iteration 1058 = 731.9976073072455
#
# Cost at iteration 1059 = 726.7628676121592
#
# Cost at iteration 1060 = 721.5637718807784
#
# Cost at iteration 1061 = 716.4000788810232
#
# Cost at iteration 1062 = 711.2715604413601
#
# Cost at iteration 1063 = 706.1776446780418
#
# Cost at iteration 1064 = 701.1180758138765
#
# Cost at iteration 1065 = 696.09293922421
#
# Cost at iteration 1066 = 691.1020549073799
#
# Cost at iteration 1067 = 686.1450753918647
#
# Cost at iteration 1068 = 681.2217277630659
#
# Cost at iteration 1069 = 676.3317690482647
#
# Cost at iteration 1070 = 671.4749343228558
#
# Cost at iteration 1071 = 666.6509551847512
#
# Cost at iteration 1072 = 661.8595702790757
#
# Cost at iteration 1073 = 657.100517400059
#
# Cost at iteration 1074 = 652.373533678245
#
# Cost at iteration 1075 = 647.6783557634377
#
# Cost at iteration 1076 = 643.014720003299
#
# Cost at iteration 1077 = 638.3823626175464
#
# Cost at iteration 1078 = 633.7810198676829
#
# Cost at iteration 1079 = 629.2104282222108
#
# Cost at iteration 1080 = 624.6703245172854
#
# Cost at iteration 1081 = 620.1604461127662
#
# Cost at iteration 1082 = 615.6805310436337
#
# Cost at iteration 1083 = 611.2303181667475
#
# Cost at iteration 1084 = 606.8095473029214
#
# Cost at iteration 1085 = 602.4179593743008
#
# Cost at iteration 1086 = 598.0552965370356
#
# Cost at iteration 1087 = 593.72130230924
#
# Cost at iteration 1088 = 589.4157216942461
#
# Cost at iteration 1089 = 585.138301299152
#
# Cost at iteration 1090 = 580.8887894486793
#
# Cost at iteration 1091 = 576.6669362943568
#
# Cost at iteration 1092 = 572.4724939190475
#
# Cost at iteration 1093 = 568.3052164368489
#
# Cost at iteration 1094 = 564.1648600883949
#
# Cost at iteration 1095 = 560.05118333159
#
# Cost at iteration 1096 = 555.9639469278202
#
# Cost at iteration 1097 = 551.9029121242743
#
# Cost at iteration 1098 = 547.8678350478314
#
# Cost at iteration 1099 = 543.8584948572686
#
# Cost at iteration 1100 = 539.874662294836
#
# Cost at iteration 1101 = 535.9161107712117
#
# Cost at iteration 1102 = 531.9826164255569
#
# Cost at iteration 1103 = 528.0739581814021
#
# Cost at iteration 1104 = 524.1899177984392
#
# ...
#
# Cost at iteration 1647 = 21.940529756389534
#
# Cost at iteration 1648 = 21.898239845424804
#
# Cost at iteration 1649 = 21.85608736255013
#
# Cost at iteration 1650 = 21.814071039947898
#
# Cost at iteration 1651 = 21.772189628579095
#
# Cost at iteration 1652 = 21.730441897889367
#
# Cost at iteration 1653 = 21.688826635519305
#
# Cost at iteration 1654 = 21.647342647019364
#
# Cost at iteration 1655 = 21.605988755568887
#
# Cost at iteration 1656 = 21.56476380169966
#
# Cost at iteration 1657 = 21.523666643023436
#
# Cost at iteration 1658 = 21.482696153963847
#
# Cost at iteration 1659 = 21.441851225492247
#
# Cost at iteration 1660 = 21.40113076486776
#
# Cost at iteration 1661 = 21.3605336953811
#
# Cost at iteration 1662 = 21.320058956102564
#
# Cost at iteration 1663 = 21.27970550163375
#
# Cost at iteration 1664 = 21.23947230186313
#
# Cost at iteration 1665 = 21.19935834172527
#
# Cost at iteration 1666 = 21.159362620964142
#
# Cost at iteration 1667 = 21.119484153899535
#
# Cost at iteration 1668 = 21.0797219691974
#
# Cost at iteration 1669 = 21.040075109643823
#
# Cost at iteration 1670 = 21.000542631922336
#
# Cost at iteration 1671 = 20.961123606394555
#
# Cost at iteration 1672 = 20.921817116884455
#
# Cost at iteration 1673 = 20.88262226046603
#
# Cost at iteration 1674 = 20.843538147253778
#
# Cost at iteration 1675 = 20.80456390019718
#
# Cost at iteration 1676 = 20.765698654877674
#
# Cost at iteration 1677 = 20.726941559309168
#
# Cost at iteration 1678 = 20.688291773741618
#
# Cost at iteration 1679 = 20.64974847046757
#
# Cost at iteration 1680 = 20.611310833631766
#
# Cost at iteration 1681 = 20.572978059043777
#
# Cost at iteration 1682 = 20.53474935399344
#
# Cost at iteration 1683 = 20.496623937069348
#
# Cost at iteration 1684 = 20.45860103797996
#
# Cost at iteration 1685 = 20.42067989737768
#
# Cost at iteration 1686 = 20.382859766685716
#
# Cost at iteration 1687 = 20.345139907927443
#
# Cost at iteration 1688 = 20.307519593558684
#
# Cost at iteration 1689 = 20.26999810630252
#
# Cost at iteration 1690 = 20.23257473898659
#
# Cost at iteration 1691 = 20.195248794383215
#
# Cost at iteration 1692 = 20.158019585051708
#
# Cost at iteration 1693 = 20.12088643318347
#
# Cost at iteration 1694 = 20.08384867044927
#
# Cost at iteration 1695 = 20.046905637849143
#
# Cost at iteration 1696 = 20.01005668556458
#
# Cost at iteration 1697 = 19.97330117281293
#
# Cost at iteration 1698 = 19.93663846770429
#
# Cost at iteration 1699 = 19.90006794710053
#
# Cost at iteration 1700 = 19.863588996476633
#
# Cost at iteration 1701 = 19.827201009784098
#
# Cost at iteration 1702 = 19.790903389316732
#
# Cost at iteration 1703 = 19.75469554557829
#
# Cost at iteration 1704 = 19.718576897152477
#
# Cost at iteration 1705 = 19.68254687057479
#
# Cost at iteration 1706 = 19.646604900206498
#
# Cost at iteration 1707 = 19.61075042811063
#
# Cost at iteration 1708 = 19.574982903929985
#
# Cost at iteration 1709 = 19.539301784766913
#
# Cost at iteration 1710 = 19.50370653506514
#
# Cost at iteration 1711 = 19.46819662649349
#
# Cost at iteration 1712 = 19.43277153783135
#
# Cost at iteration 1713 = 19.39743075485596
#
# Cost at iteration 1714 = 19.36217377023177
#
# Cost at iteration 1715 = 19.32700008340113
#
# Cost at iteration 1716 = 19.291909200476997
#
# Cost at iteration 1717 = 19.256900634137402
#
# Cost at iteration 1718 = 19.221973903521395
#
# Cost at iteration 1719 = 19.18712853412677
#
# Cost at iteration 1720 = 19.152364057709416
#
# Cost at iteration 1721 = 19.117680012184366
#
# Cost at iteration 1722 = 19.08307594152811
#
# Cost at iteration 1723 = 19.0485513956829
#
# Cost at iteration 1724 = 19.014105930462396
#
# Cost at iteration 1725 = 18.979739107458585
#
# Cost at iteration 1726 = 18.945450493950645
#
# Cost at iteration 1727 = 18.91123966281499
#
# Cost at iteration 1728 = 18.8771061924367
# Cost at iteration 1729 = 18.843049666622623
#
# Cost at iteration 1730 = 18.809069674515623
#
# Cost at iteration 1731 = 18.775165810510398
#
# Cost at iteration 1732 = 18.74133767417038
#
# Cost at iteration 1733 = 18.70758487014652
#
# Cost at iteration 1734 = 18.673907008096556
#
# Cost at iteration 1735 = 18.640303702606403
#
# Cost at iteration 1736 = 18.606774573112187
#
# Cost at iteration 1737 = 18.57331924382401
#
# Cost at iteration 1738 = 18.539937343650475
#
# Cost at iteration 1739 = 18.506628506124887
#
# Cost at iteration 1740 = 18.47339236933227
#
# Cost at iteration 1741 = 18.440228575837764
#
# Cost at iteration 1742 = 18.407136772616248
#
# Cost at iteration 1743 = 18.374116610982664
#
# Cost at iteration 1744 = 18.341167746524096
#
# Cost at iteration 1745 = 18.308289839032543
#
# Cost at iteration 1746 = 18.275482552438653
#
# Cost at iteration 1747 = 18.242745554747028
#
# Cost at iteration 1748 = 18.21007851797205
#
# Cost at iteration 1749 = 18.177481118075118
#
# Cost at iteration 1750 = 18.14495303490268
#
# Cost at iteration 1751 = 18.112493952125284
#
# Cost at iteration 1752 = 18.080103557177814
#
# Cost at iteration 1753 = 18.047781541200422
#
# Cost at iteration 1754 = 18.015527598980555
#
# Cost at iteration 1755 = 17.983341428895937
#
# Cost at iteration 1756 = 17.95122273285843
#
# Cost at iteration 1757 = 17.91917121625879
#
# Cost at iteration 1758 = 17.887186587912378
#
# Cost at iteration 1759 = 17.8552685600056
#
# Cost at iteration 1760 = 17.823416848043536
#
# Cost at iteration 1761 = 17.791631170797956
#
# Cost at iteration 1762 = 17.75991125025662
#
# Cost at iteration 1763 = 17.72825681157317
#
# Cost at iteration 1764 = 17.696667583017668
#
# Cost at iteration 1765 = 17.665143295928473
#
# Cost at iteration 1766 = 17.633683684664355
#
# Cost at iteration 1767 = 17.602288486557537
#
# Cost at iteration 1768 = 17.57095744186775
#
# Cost at iteration 1769 = 17.539690293736715
#
# Cost at iteration 1770 = 17.508486788143436
#
# Cost at iteration 1771 = 17.477346673860414
#
# Cost at iteration 1772 = 17.446269702410284
#
# Cost at iteration 1773 = 17.415255416554004
#
# Cost at iteration 1774 = 17.38429757332878
#
# Cost at iteration 1775 = 17.353402165068402
#
# Cost at iteration 1776 = 17.322568953895967
#
# Cost at iteration 1777 = 17.29179770447795
#
# Cost at iteration 1778 = 17.261088183984956
#
# Cost at iteration 1779 = 17.230440162053128
#
# Cost at iteration 1780 = 17.19985341074635
#
# Cost at iteration 1781 = 17.169327704518878
#
# Cost at iteration 1782 = 17.138862820178755
#
# Cost at iteration 1783 = 17.108458536851575
#
# Cost at iteration 1784 = 17.078114635945173
#
# Cost at iteration 1785 = 17.047830901114466
#
# Cost at iteration 1786 = 17.017607118227335
#
# Cost at iteration 1787 = 16.987443075330685
#
# Cost at iteration 1788 = 16.957338562617196
#
# Cost at iteration 1789 = 16.927293372392654
#
# Cost at iteration 1790 = 16.897307299043817
#
# Cost at iteration 1791 = 16.867380139006627
#
# Cost at iteration 1792 = 16.837511690735145
#
# Cost at iteration 1793 = 16.807701754670955
#
# Cost at iteration 1794 = 16.777950133212993
#
# Cost at iteration 1795 = 16.748256630687806
#
# Cost at iteration 1796 = 16.71862105332056
#
# Cost at iteration 1797 = 16.689043209206158
#
# Cost at iteration 1798 = 16.659522908281183
#
# Cost at iteration 1799 = 16.630059962296013
#
# Cost at iteration 1800 = 16.600654184787516
#
# Cost at iteration 1801 = 16.571305391052242
#
# Cost at iteration 1802 = 16.542013398119884
#
# Cost at iteration 1803 = 16.51277802472739
#
# Cost at iteration 1804 = 16.48359909129327
#
# Cost at iteration 1805 = 16.454476419892455
#
# Cost at iteration 1806 = 16.425409834231544
#
# Cost at iteration 1807 = 16.396399159624462
#
# Cost at iteration 1808 = 16.36744422296845
#
# Cost at iteration 1809 = 16.33854485272052
#
# Cost at iteration 1810 = 16.309700878874217
#
# Cost at iteration 1811 = 16.280912132936898
#
# Cost at iteration 1812 = 16.25217844790719
#
# Cost at iteration 1813 = 16.223499658252898
#
# Cost at iteration 1814 = 16.194875599889382
#
# Cost at iteration 1815 = 16.16630611015805
#
# Cost at iteration 1816 = 16.137791027805456
#
# Cost at iteration 1817 = 16.109330192962506
#
# Cost at iteration 1818 = 16.080923447124203
#
# Cost at iteration 1819 = 16.052570633129587
#
# Cost at iteration 1820 = 16.024271595141958
#
# Cost at iteration 1821 = 15.996026178629702
#
# Cost at iteration 1822 = 15.967834230346966
#
# Cost at iteration 1823 = 15.939695598315119
#
# Cost at iteration 1824 = 15.911610131804137
#
# Cost at iteration 1825 = 15.883577681314687
#
# Cost at iteration 1826 = 15.855598098559987
#
# Cost at iteration 1827 = 15.827671236448314
#
# Cost at iteration 1828 = 15.799796949065936
#
# Cost at iteration 1829 = 15.771975091659808
#
# Cost at iteration 1830 = 15.744205520621032
#
# Cost at iteration 1831 = 15.716488093468273
#
# Cost at iteration 1832 = 15.68882266883167
#
# Cost at iteration 1833 = 15.6612091064369
#
# Cost at iteration 1834 = 15.633647267089378
#
# Cost at iteration 1835 = 15.606137012658964
#
# Cost at iteration 1836 = 15.57867820606478
#
# Cost at iteration 1837 = 15.551270711260173
#
# Cost at iteration 1838 = 15.523914393218162
#
# Cost at iteration 1839 = 15.496609117916924
#
# Cost at iteration 1840 = 15.469354752325515
#
# Cost at iteration 1841 = 15.442151164390044
#
# Cost at iteration 1842 = 15.414998223019724
#
# Cost at iteration 1843 = 15.387895798073492
#
# Cost at iteration 1844 = 15.360843760346588
#
# Cost at iteration 1845 = 15.333841981557466
#
# Cost at iteration 1846 = 15.306890334334922
#
# Cost at iteration 1847 = 15.279988692205357
#
# Cost at iteration 1848 = 15.25313692958032
#
# Cost at iteration 1849 = 15.226334921744293
#
# Cost at iteration 1850 = 15.19958254484243
#
# Cost at iteration 1851 = 15.172879675868874
#
# Cost at iteration 1852 = 15.146226192654836
#
# Cost at iteration 1853 = 15.119621973857264
#
# Cost at iteration 1854 = 15.09306689894744
#
# Cost at iteration 1855 = 15.06656084819978
#
# Cost at iteration 1856 = 15.040103702680993
#
# Cost at iteration 1857 = 15.013695344239142
#
# Cost at iteration 1858 = 14.987335655493146
#
# Cost at iteration 1859 = 14.961024519822198
#
# Cost at iteration 1860 = 14.934761821355638
#
# Cost at iteration 1861 = 14.908547444962743
#
# Cost at iteration 1862 = 14.88238127624272
#
# Cost at iteration 1863 = 14.856263201515072
#
# Cost at iteration 1864 = 14.830193107809722
#
# Cost at iteration 1865 = 14.80417088285775
#
# Cost at iteration 1866 = 14.778196415081958
#
# Cost at iteration 1867 = 14.752269593587622
#
# Cost at iteration 1868 = 14.726390308153594
#
# Cost at iteration 1869 = 14.700558449223232
#
# Cost at iteration 1870 = 14.67477390789589
#
# Cost at iteration 1871 = 14.649036575917997
#
# Cost at iteration 1872 = 14.623346345674772
#
# Cost at iteration 1873 = 14.597703110181879
#
# Cost at iteration 1874 = 14.572106763077151
#
# Cost at iteration 1875 = 14.546553218816356
#
# Cost at iteration 1876 = 14.520897970415154
#
# Cost at iteration 1877 = 14.495289923041426
#
# Cost at iteration 1878 = 14.469728971725031
#
# Cost at iteration 1879 = 14.44421501207033
#
# Cost at iteration 1880 = 14.418747940249023
#
# Cost at iteration 1881 = 14.393327652992719
#
# Cost at iteration 1882 = 14.367954047586036
#
# Cost at iteration 1883 = 14.342627021859752
#
# Cost at iteration 1884 = 14.317346474183712
#
# Cost at iteration 1885 = 14.292112303460394
#
# Cost at iteration 1886 = 14.26692440911805
#
# Cost at iteration 1887 = 14.241782691104335
#
# Cost at iteration 1888 = 14.216687049879788
#
# Cost at iteration 1889 = 14.19163738641169
#
# Cost at iteration 1890 = 14.166633602167664
#
# Cost at iteration 1891 = 14.141675599109629
#
# Cost at iteration 1892 = 14.116469213913627
#
# Cost at iteration 1893 = 14.091120632860944
#
# Cost at iteration 1894 = 14.065819925971825
#
# Cost at iteration 1895 = 14.040566991695183
#
# Cost at iteration 1896 = 14.015377297532979
#
# Cost at iteration 1897 = 13.990835626061328
#
# Cost at iteration 1898 = 13.966338989947458
#
# Cost at iteration 1899 = 13.941929935665494
#
# Cost at iteration 1900 = 13.91761711523668
#
# Cost at iteration 1901 = 13.893348749445291
#
# Cost at iteration 1902 = 13.869124743211168
#
# Cost at iteration 1903 = 13.844945001908407
#
# Cost at iteration 1904 = 13.820809431360145
#
# Cost at iteration 1905 = 13.79671793783324
#
# Cost at iteration 1906 = 13.77267042803324
#
# Cost at iteration 1907 = 13.748666809099268
#
# Cost at iteration 1908 = 13.724706988599065
#
# Cost at iteration 1909 = 13.700860792731449
#
# Cost at iteration 1910 = 13.677139141935637
#
# Cost at iteration 1911 = 13.653460587192082
#
# Cost at iteration 1912 = 13.62982503812826
#
# Cost at iteration 1913 = 13.60623240478471
#
# Cost at iteration 1914 = 13.582682597610283
#
# Cost at iteration 1915 = 13.559175527457597
#
# Cost at iteration 1916 = 13.535711105578386
#
# Cost at iteration 1917 = 13.51228924361928
#
# Cost at iteration 1918 = 13.488909853617063
#
# Cost at iteration 1919 = 13.46557284799467
#
# Cost at iteration 1920 = 13.442278139556695
#
# Cost at iteration 1921 = 13.419025641485348
#
# Cost at iteration 1922 = 13.395815267336223
#
# Cost at iteration 1923 = 13.372646931034263
#
# Cost at iteration 1924 = 13.34952054686976
#
# Cost at iteration 1925 = 13.326436029494344
#
# Cost at iteration 1926 = 13.303393293917225
#
# Cost at iteration 1927 = 13.28039225550115
#
# Cost at iteration 1928 = 13.257432829958923
#
# Cost at iteration 1929 = 13.234514933349374
#
# Cost at iteration 1930 = 13.211638482073937
#
# Cost at iteration 1931 = 13.188803392872924
#
# Cost at iteration 1932 = 13.166009582822014
#
# Cost at iteration 1933 = 13.143256969328759
#
# Cost at iteration 1934 = 13.1205454701291
#
# Cost at iteration 1935 = 13.09787500328404
#
# Cost at iteration 1936 = 13.07524548717623
#
# Cost at iteration 1937 = 13.0526568405067
#
# Cost at iteration 1938 = 13.030108982291672
#
# Cost at iteration 1939 = 13.007601831859274
#
# Cost at iteration 1940 = 12.98513530884645
#
# Cost at iteration 1941 = 12.962736322613198
#
# Cost at iteration 1942 = 12.940460748920582
#
# Cost at iteration 1943 = 12.918225280192603
#
# Cost at iteration 1944 = 12.89602983760967
#
# Cost at iteration 1945 = 12.873874342650133
#
# Cost at iteration 1946 = 12.85175871708741
#
# Cost at iteration 1947 = 12.829682882986916
#
# Cost at iteration 1948 = 12.807646762703408
#
# Cost at iteration 1949 = 12.785650278877945
#
# Cost at iteration 1950 = 12.763693354435286
#
# Cost at iteration 1951 = 12.741775912580957
#
# Cost at iteration 1952 = 12.719897876798687
#
# Cost at iteration 1953 = 12.698059170847635
#
# Cost at iteration 1954 = 12.676259718759841
#
# Cost at iteration 1955 = 12.654499444837603
#
# Cost at iteration 1956 = 12.632778273650883
#
# Cost at iteration 1957 = 12.61109613003484
#
# Cost at iteration 1958 = 12.589452939087337
#
# Cost at iteration 1959 = 12.56784862616651
#
# Cost at iteration 1960 = 12.546283116888285
#
# Cost at iteration 1961 = 12.524756337124106
#
# Cost at iteration 1962 = 12.503268212998524
#
# Cost at iteration 1963 = 12.481818670886883
#
# Cost at iteration 1964 = 12.460407637413118
#
# Cost at iteration 1965 = 12.439035039447427
#
# Cost at iteration 1966 = 12.417700804104145
#
# Cost at iteration 1967 = 12.396404858739457
#
# Cost at iteration 1968 = 12.375147130949333
#
# Cost at iteration 1969 = 12.353927548567428
#
# Cost at iteration 1970 = 12.33274603966293
#
# Cost at iteration 1971 = 12.311602532538496
#
# Cost at iteration 1972 = 12.290496955728328
#
# Cost at iteration 1973 = 12.269429237996054
#
# Cost at iteration 1974 = 12.248399308332814
#
# Cost at iteration 1975 = 12.227407095955309
#
# Cost at iteration 1976 = 12.206452530303846
#
# Cost at iteration 1977 = 12.185535541040554
#
# Cost at iteration 1978 = 12.164656058047392
#
# Cost at iteration 1979 = 12.143814011424377
#
# Cost at iteration 1980 = 12.123009331487799
#
# Cost at iteration 1981 = 12.102241948768324
#
# Cost at iteration 1982 = 12.081511794009375
#
# Cost at iteration 1983 = 12.06081879816526
#
# Cost at iteration 1984 = 12.040162892399605
#
# Cost at iteration 1985 = 12.01954400808347
#
# Cost at iteration 1986 = 11.99896207679391
#
# Cost at iteration 1987 = 11.978417030312121
#
# Cost at iteration 1988 = 11.957908800621931
#
# Cost at iteration 1989 = 11.93743731990818
#
# Cost at iteration 1990 = 11.917002520555174
#
# Cost at iteration 1991 = 11.896604335145035
#
# Cost at iteration 1992 = 11.876242696456243
#
# Cost at iteration 1993 = 11.855917537462137
#
# Cost at iteration 1994 = 11.8356287913293
#
# Cost at iteration 1995 = 11.81536645083717
#
# Cost at iteration 1996 = 11.795126263813485
#
# Cost at iteration 1997 = 11.774922369420079
#
# Cost at iteration 1998 = 11.754754701380385
#
# Cost at iteration 1999 = 11.734623193603895
#
# Cost at iteration 2000 = 11.714527780184898
#
# average_cost:  1392.0814337005856
# Root Mean Squared Error on Training Data = 106.16630876047242
# Root Mean Squared Error on Test Data = 104.0461642061184

# %%
plt.plot(np.linspace(1,2000,2000), error)
plt.xlabel('Iteration')
plt.ylabel('MSE error')
plt.title('Error curve')
# Out:
# Text(0.5, 1.0, 'Error curve')

# %%
plt.plot(np.linspace(1,2000,2000), accuracy)
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.title('Accuracy curve')
# Out:
# Text(0.5, 1.0, 'Accuracy curve')

# %% [markdown]
# ## Question
#
# Answer the following questions:
# 1. What is the activation function that you will choose for the output layer? Justify your answer
# briefly.
# 2. How many neurons should there be in the output layer? Why?
# 3. Report the average MSE loss and the accuracy.
# 4. Plot the loss and accuracy as a function of the number of iterations.
# 5. What is the effect of the learning rate on the training process? Vary the learning rate to be
# between 0.001 and 1.0 and plot the resulting accuracy as a function of learning rate.
# 6. What is the effect of the number of neurons in the hidden layer? To answer this question,
# you will need to consider and answer the following:
# a. You will need to vary the number of neurons from 1 to 10. Does the update rule
# need to be changed/derived again? Why or why not?
# b. Report your observations by reporting the final loss and plotting the true labels and
# your predicted labels, along with a brief (2-3 lines) description.
# 7. What is the effect of the activation functions in the network? Explore two different activation
# functions other than sigmoid such as tanh, linear, or ReLU.
# a. Will you need to change the update rule?
# b. What is the change that you need to make to achieve this experiment?
# c. Report your observations by reporting the final loss and plotting the true labels and
# your predicted labels, along with a brief (2-3 lines) description.

# %% [markdown]
# ## Answers

# %% [markdown]
# 1. I would use a relu activation fucntion since caps the output between 0 to infinity.

# %% [markdown]
# 2. There would be only one neuron in the output layers as it is just predicting a singlular value.

# %% [markdown]
# 3. The lowest MSE obtained was 0.579 and the average MSE is 485.885.
# Root Mean Squared Error on Training Data = 106.315
# Root Mean Squared Error on Test Data = 104.963

# %% [markdown]
# ### 4. Ans:

# %%
plt.plot(np.linspace(1,2000,2000), error)
plt.xlabel('Iteration')
plt.ylabel('MSE error)')
plt.title('Error curve')
plt.show()
plt.plot(np.linspace(1,2000,2000), accuracy)
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.title('Accuracy curve')
plt.show()

# %% [markdown]
# ### 5. Ans:
# Learning rate is important for reaching convergence and also to select the optimum number of epochs.

# %%
plt.plot(np.linspace(1,2000,2000), accuracy)
plt.xlabel('Iteration')
plt.ylabel('Accuracy)')
plt.title('Learning rate: %.2f' %learning_rate)
plt.show()

# %%
plt.plot(np.linspace(1,2000,2000), accuracy)
plt.xlabel('Iteration')
plt.ylabel('Accuracy)')
plt.title('Learning rate: %.2f' %learning_rate)
plt.show()

# %%
plt.plot(np.linspace(1,2000,2000), accuracy)
plt.xlabel('Iteration')
plt.ylabel('Accuracy)')
plt.title('Learning rate: %.2f' %learning_rate)
plt.show()

# %% [markdown]
# ### 6. Ans:
# layer_sizes = [2, 8, 1]
# where the second value is the number of neurons in my code. For me 8 neurons were my optimal neurons.
# Varying the neurons did not change my update rule as they are multiplied with the bias and summed up once for only 1 hidden layer. However if I reduce the number of neurons, my model will be underfit and too many of them will make it overfit.

# %%
layer_sizes = [2, 2, 1]                                                           #set layer sizes
num_iters = 2000                                                                  #set epochs
learning_rate = 0.01                                                              #set learning rate
params, error, accuracy = model(X_train, Y_train, layer_sizes, num_iters, learning_rate)           #train the model
train_acc, test_acc = compute_accuracy(X_train, X_test, Y_train, Y_test, params)  #get accuracy
print('Root Mean Squared Error on Training Data = ' + str(train_acc))
print('Root Mean Squared Error on Test Data = ' + str(test_acc))

plt.plot(np.linspace(1,2000,2000), error)
plt.xlabel('Iteration')
plt.ylabel('MSE error')
plt.title('Error curve')
plt.show()
# Out:
# Cost at iteration 1 = 2858.3597535268773
#
# Cost at iteration 101 = 2857.7174002648203
#
# Cost at iteration 201 = 2857.08289890323
#
# Cost at iteration 301 = 2856.43971358983
#
# Cost at iteration 401 = 2855.7289314076374
#
# Cost at iteration 501 = 2854.7332746458364
#
# Cost at iteration 601 = 2852.6482911137928
#
# Cost at iteration 701 = 2846.5060823584304
#
# Cost at iteration 801 = 2825.5060330361002
#
# Cost at iteration 901 = 2752.221539554072
#
# Cost at iteration 1001 = 2518.302496455671
#
# Cost at iteration 1101 = 1973.5442032202616
#
# Cost at iteration 1201 = 1369.2168831722508
#
# Cost at iteration 1301 = 1162.7530796055046
#
# Cost at iteration 1401 = 1161.6176889908756
#
# Cost at iteration 1501 = 1179.0429915479301
#
# Cost at iteration 1601 = 1191.220220736854
#
# Cost at iteration 1701 = 1198.199647252695
#
# Cost at iteration 1801 = 1201.5475678925413
#
# Cost at iteration 1901 = 1203.239860665555
#
# average_cost:  2087.830324281747
# Root Mean Squared Error on Training Data = 93.50917837661795
# Root Mean Squared Error on Test Data = 89.41455407257855

# %%
layer_sizes = [2, 12, 1]                                                           #set layer sizes
num_iters = 2000                                                                  #set epochs
learning_rate = 0.01                                                              #set learning rate
params, error, accuracy = model(X_train, Y_train, layer_sizes, num_iters, learning_rate)           #train the model
train_acc, test_acc = compute_accuracy(X_train, X_test, Y_train, Y_test, params)  #get accuracy
print('Root Mean Squared Error on Training Data = ' + str(train_acc))
print('Root Mean Squared Error on Test Data = ' + str(test_acc))

plt.plot(np.linspace(1,2000,2000), error)
plt.xlabel('Iteration')
plt.ylabel('MSE error')
plt.title('Error curve')
plt.show()
# Out:
# Cost at iteration 1 = 2858.416060962643
#
# Cost at iteration 101 = 2857.7306456372994
#
# Cost at iteration 201 = 2856.995796719215
#
# Cost at iteration 301 = 2856.0350045617693
#
# Cost at iteration 401 = 2854.2702242228984
#
# Cost at iteration 501 = 2849.7030866281216
#
# Cost at iteration 601 = 2835.344342013604
#
# Cost at iteration 701 = 2787.067290297218
#
# Cost at iteration 801 = 2628.4776571450134
#
# Cost at iteration 901 = 2189.157546395628
#
# Cost at iteration 1001 = 1437.5649123449184
#
# Cost at iteration 1101 = 847.2985161369223
#
# Cost at iteration 1201 = 511.5026418483349
#
# Cost at iteration 1301 = 267.51500993444375
#
# Cost at iteration 1401 = 129.38086808511758
#
# Cost at iteration 1501 = 74.02913623991263
#
# Cost at iteration 1601 = 52.72818264414735
#
# Cost at iteration 1701 = 41.543731446381656
#
# Cost at iteration 1801 = 33.87264697329951
#
# Cost at iteration 1901 = 27.888463106850555
#
# average_cost:  1479.6667509858603
# Root Mean Squared Error on Training Data = 105.98729653135808
# Root Mean Squared Error on Test Data = 103.64502305462803

# %% [markdown]
# ### 7. Ans:
